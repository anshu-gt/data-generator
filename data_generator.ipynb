# %%
# !pip install rstr
# !pip install names
# Out:
# Requirement already satisfied: rstr in /Users/anshusingh/.pyenv/versions/3.8.11/lib/python3.8/site-packages (3.2.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: names in /Users/anshusingh/.pyenv/versions/3.8.11/lib/python3.8/site-packages (0.3.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

import names
import rstr

# %% [markdown]
# #### Generates the below attributes
# Name
# NRIC
# Gender
# BMI
# Blood Type
# Disease
# Age
# Zipcode

# %%
# attributes 
gender_types = ['M', 'F']
blood_types = ["A", "B", "AB", "O"]

diseases = ['Nipah', 'COVID-19','Influenza', 'Chikungunya', 'Cholera', 'Dengue', 'Mumps','Diphtheria', 'Pneumococcal',
 'HIV/ AIDS', 'Hepatitis', 'Anthrax', 'Food Poisoning', 'Typhoid', 'Malaria', 'Plague', 'Chickenpox', 'Tuberculosis',
 'Conjunctivitis', 'Rabies', 'Measles', 'Rubella', 'Smallpox']

age_range = [18, 90]
zipcode_range = [100000, 809999]
bmi_range = [18.5, 39.9]

# generator
def generate_nric(): 
    return rstr.xeger(r'^[STFG]\d{7}[A-Z]$')

# defaults 
NO_OF_ROWS = 1000
FILENAME = "simulated_hospital_data.csv"

# %%
def create_simulated_data(no_of_records=NO_OF_ROWS, add_missing_values):
    simulated_data = pd.DataFrame()     
    
    simulated_data["NRIC"] = [generate_nric() for _ in range(0, no_of_records)]
    
    simulated_data["Name"] = [names.get_full_name() for _ in range(0, no_of_records)]
    simulated_data["Gender"]= np.random.choice(gender_types, size=no_of_records)
    simulated_data["BloodType"] = np.random.choice(blood_types, size=no_of_records)
    simulated_data["Disease"] = np.random.choice(diseases, size=no_of_records)
    
    simulated_data["Age"] = np.random.randint(low=age_range[0], high=age_range[1], size=(no_of_records,))
    simulated_data["Zipcode"] = np.random.randint(low=zipcode_range[0], high=zipcode_range[1], size=(no_of_records,))
    simulated_data["BMI"] = [round(np.random.uniform(bmi_range[0],bmi_range[1]), 1) for _ in range(0, no_of_records)]
    return simulated_data

# %%
simulated_data = create_simulated_data()
# np.random.shuffle(simulated_data.colA)
simulated_data.head(20)
# Out:
#          NRIC                Name Gender Blood type         Disease  Age  \
# 0   G7126736E     Julian Petersen      M          B         Anthrax   52
# 1   S8005616U      Kathleen Tibbs      F          A         Malaria   65
# 2   T5561403L        James Stokes      M          O         Rubella   51
# 3   T3487804E    James Kimberling      M          O      Chickenpox   41
# 4   G9811218V       Michael Sires      M          A     Chikungunya   45
# 5   F8330400G           Vada Cook      M          B          Plague   71
# 6   T9866423L         Eric Clarke      M         AB         Malaria   39
# 7   T6822311F        Kenneth Poll      M          O       Influenza   83
# 8   G5310992P    Katherine Michel      M          O           Nipah   25
# 9   G9415143C     Barbara Stamand      M         AB       Influenza   83
# 10  F1711155I     Zachary Johnson      F          A           Mumps   88
# 11  S6010999Y  Kimberly Chatfield      F          A          Rabies   56
# 12  S0736911E      Gustavo Ingham      F          A           Nipah   82
# 13  S8489762L       Kristy Santos      M          A        COVID-19   42
# 14  G5851978D       Kenneth Cross      F         AB  Food Poisoning   39
# 15  T6195389B       Wanda Carroll      M          B       Hepatitis   24
# 16  F4357192F    Michelle Aquirre      F          A    Tuberculosis   81
# 17  S5262809E        Kevin Nelson      M          O         Measles   38
# 18  G7415453J        Celina Brock      F          O      Diphtheria   29
# 19  G6231546G        Donald Lucas      F          B       HIV/ AIDS   64
#
#     Zipcode   BMI
# 0    717132  28.5
# 1    764269  19.0
# 2    484021  28.4
# 3    780970  26.7
# 4    609264  19.9
# 5    660831  20.9
# 6    211146  22.2
# 7    633886  21.9
# 8    315077  32.1
# 9    227629  37.1
# 10   556808  35.3
# 11   146352  39.3
# 12   110350  31.7
# 13   650866  18.7
# 14   420936  23.1
# 15   279412  24.6
# 16   345960  34.5
# 17   567932  39.5
# 18   760896  22.2
# 19   751885  19.5

# %%
np.random.shuffle(simulated_data.Disease)
simulated_data.head(20)
# Out:
# /var/folders/3l/sc82d46d2_lbr0vhyw2tf0t80000gn/T/ipykernel_6483/1440647177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   np.random.shuffle(simulated_data.Disease)
#          NRIC                Name Gender Blood type         Disease  Age  \
# 0   G7126736E     Julian Petersen      M          B       HIV/ AIDS   52
# 1   S8005616U      Kathleen Tibbs      F          A           Mumps   65
# 2   T5561403L        James Stokes      M          O        COVID-19   51
# 3   T3487804E    James Kimberling      M          O          Rabies   41
# 4   G9811218V       Michael Sires      M          A  Conjunctivitis   45
# 5   F8330400G           Vada Cook      M          B  Food Poisoning   71
# 6   T9866423L         Eric Clarke      M         AB          Rabies   39
# 7   T6822311F        Kenneth Poll      M          O      Diphtheria   83
# 8   G5310992P    Katherine Michel      M          O          Dengue   25
# 9   G9415143C     Barbara Stamand      M         AB      Chickenpox   83
# 10  F1711155I     Zachary Johnson      F          A         Typhoid   88
# 11  S6010999Y  Kimberly Chatfield      F          A         Anthrax   56
# 12  S0736911E      Gustavo Ingham      F          A      Chickenpox   82
# 13  S8489762L       Kristy Santos      M          A       HIV/ AIDS   42
# 14  G5851978D       Kenneth Cross      F         AB       HIV/ AIDS   39
# 15  T6195389B       Wanda Carroll      M          B          Rabies   24
# 16  F4357192F    Michelle Aquirre      F          A          Rabies   81
# 17  S5262809E        Kevin Nelson      M          O         Cholera   38
# 18  G7415453J        Celina Brock      F          O       HIV/ AIDS   29
# 19  G6231546G        Donald Lucas      F          B           Nipah   64
#
#     Zipcode   BMI
# 0    717132  28.5
# 1    764269  19.0
# 2    484021  28.4
# 3    780970  26.7
# 4    609264  19.9
# 5    660831  20.9
# 6    211146  22.2
# 7    633886  21.9
# 8    315077  32.1
# 9    227629  37.1
# 10   556808  35.3
# 11   146352  39.3
# 12   110350  31.7
# 13   650866  18.7
# 14   420936  23.1
# 15   279412  24.6
# 16   345960  34.5
# 17   567932  39.5
# 18   760896  22.2
# 19   751885  19.5

# %%
simulated_data.to_csv(FILENAME, mode='w', index=False)
