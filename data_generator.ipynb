# %%
# !pip install rstr
# !pip install names
# Out:
# Requirement already satisfied: rstr in /Users/anshusingh/.pyenv/versions/3.8.11/lib/python3.8/site-packages (3.2.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: names in /Users/anshusingh/.pyenv/versions/3.8.11/lib/python3.8/site-packages (0.3.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import random
import datetime 
import pandas as pd
import numpy as np

import names
import rstr

# %% [markdown]
# #### Generates the below attributes
# - Name
# - NRIC
# - Gender
# - BMI
# - Blood Type
# - Disease
# - Age
# - Zipcode
# - Date of Diagnosis

# %%
# defaults 
NO_OF_ROWS = 1000
FILENAME = "simulated_hospital_data.csv"

# %%
# --------------------
# Attributes' domain 
# --------------------

gender_types = ['M', 'F']
blood_types = ["A", "B", "AB", "O"]

diseases = ['Nipah', 'COVID-19','Influenza', 'Chikungunya', 'Cholera', 'Dengue', 'Mumps','Diphtheria', 'Pneumococcal',
 'HIV/ AIDS', 'Hepatitis', 'Anthrax', 'Food Poisoning', 'Typhoid', 'Malaria', 'Plague', 'Chickenpox', 'Tuberculosis',
 'Conjunctivitis', 'Rabies', 'Measles', 'Rubella', 'Smallpox']

age_range = [18, 90]
zipcode_range = [100000, 809999]
bmi_range = [18.5, 39.9]

# %%
# random date generator
START_DATE_STR = "1990-01-22"
END_DATE_STR = "2022-07-30"
DATE_FORMAT = "%Y-%m-%d"

start_date = datetime.datetime.strptime(START_DATE_STR, DATE_FORMAT)
end_date = datetime.datetime.strptime(END_DATE_STR, DATE_FORMAT)

def generate_random_date(start=start_date, end=end_date, date_format=DATE_FORMAT):
    """Generate a random datetime between `start` and `end`"""
    random_datetime =  start + datetime.timedelta(
        # Get a random amount of seconds between `start` and `end`
        seconds=random.randint(0, int((end - start).total_seconds())),
    )
    return datetime.datetime.strftime(random_datetime, date_format)

# %%
# NRIC generator
def generate_nric(): 
    return rstr.xeger(r'^[STFG]\d{7}[A-Z]$')

# %%
def create_simulated_data(no_of_records=NO_OF_ROWS):
    simulated_data = pd.DataFrame()     
    
    simulated_data["NRIC"] = [generate_nric() for _ in range(0, no_of_records)]
    
    simulated_data["Name"] = [names.get_full_name() for _ in range(0, no_of_records)]
    simulated_data["Gender"]= np.random.choice(gender_types, size=no_of_records)
    simulated_data["BloodType"] = np.random.choice(blood_types, size=no_of_records)
    simulated_data["Disease"] = np.random.choice(diseases, size=no_of_records)
    
    simulated_data["Age"] = np.random.randint(low=age_range[0], high=age_range[1], size=(no_of_records,))
    simulated_data["Zipcode"] = np.random.randint(low=zipcode_range[0], high=zipcode_range[1], size=(no_of_records,))
    simulated_data["BMI"] = [round(np.random.uniform(bmi_range[0], bmi_range[1]), 1) for _ in range(0, no_of_records)]
    
    simulated_data["DateOfDiagnosis"] = [generate_random_date() for _ in range(0, no_of_records)]
    
    return simulated_data

# %%
simulated_data = create_simulated_data()
# np.random.shuffle(simulated_data.colA)
simulated_data.head(20)
# Out:
#          NRIC                   Name Gender BloodType         Disease  Age  \
# 0   S6824336D              Rosa Link      F         A          Plague   48
# 1   F4649455D         Albert Bussell      F         B           Nipah   78
# 2   G0110905P       Michelle Brocato      M         O       Influenza   74
# 3   S8740619M       Hubert Hornbrook      F         A         Rubella   66
# 4   T5836229K      Arthur Kasprowicz      M         O    Pneumococcal   51
# 5   S5897104O       Ernestine Bonine      F         A       Hepatitis   64
# 6   T8207300F            Donna Kuker      M        AB  Conjunctivitis   59
# 7   G2640908V  Christopher Moriarity      F         O         Typhoid   39
# 8   G2388812X     Georgia Mcclelland      F        AB          Dengue   46
# 9   T4058083P        Gregory Bolanos      F        AB     Chikungunya   72
# 10  T2351085M          Melissa Myers      M        AB      Diphtheria   84
# 11  S5041244K            Steven Boyd      F         B          Rabies   51
# 12  G3152513H          Leona Servoss      F        AB         Typhoid   72
# 13  S3940555V       Charles Phillips      F        AB     Chikungunya   24
# 14  S4336799W          Andres Marcum      M         B         Malaria   73
# 15  G7315045O            Henry Daley      F        AB           Mumps   18
# 16  T8960971T          Gloria Rhodes      F         A         Rubella   31
# 17  F3756169A           Kera Demello      F         B  Food Poisoning   85
# 18  S0249041A           John Haywood      M         O          Rabies   22
# 19  G8987135O          Michael Beach      M         A  Food Poisoning   54
#
#     Zipcode   BMI DateOfDiagnosis
# 0    744623  37.6      2008-01-31
# 1    164990  21.3      1992-10-14
# 2    392735  33.8      2009-05-28
# 3    661742  38.6      2006-04-20
# 4    333119  27.4      2006-06-14
# 5    235010  27.7      2008-02-01
# 6    756419  21.5      1999-03-29
# 7    130380  35.2      2002-09-17
# 8    242994  21.9      2016-07-06
# 9    646799  25.0      2019-10-24
# 10   293342  37.4      1999-07-08
# 11   263163  22.2      1999-02-22
# 12   140945  18.5      2014-06-20
# 13   349309  32.0      2014-06-24
# 14   185016  36.5      2019-06-24
# 15   671532  26.6      2004-03-28
# 16   208021  31.2      2007-11-30
# 17   404798  26.4      2002-10-10
# 18   223303  31.9      1993-06-03
# 19   539796  38.5      1998-05-24

# %%
# np.random.shuffle(simulated_data.Disease)
# simulated_data.head(20)

# %%
simulated_data.to_csv(FILENAME, mode='w', index=False)
